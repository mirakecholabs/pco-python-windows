# %% [markdown]
# # PCO Jupyter Notebook Example

# %% [markdown]
# https://www.excelitas.com/de/product/pco-software-development-kits#custom-tab-python

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import pco

# %% [markdown]
# Create pco.Camera object, start recording and copy image:

# %%
with pco.Camera() as cam:

    cam.record()
    image, meta = cam.image()

# %% [markdown]
# Show recorded image and histogram using matplotlib:

# %%
fig, (ax0, ax1) = plt.subplots(ncols=2, figsize=(10, 4))

im0 = ax0.imshow(image, cmap='cool')
fig.colorbar(im0, ax=ax0)
ax0.set_title('Image')
ax0.axis('off')

ax1.hist(image.ravel(), 512)
ax1.set_title('Histogram')

fig.tight_layout()
